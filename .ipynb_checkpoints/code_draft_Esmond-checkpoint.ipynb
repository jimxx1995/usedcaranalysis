# %%
import requests_cache

# %%
requests_cache.install_cache('craigslist_cache')

# %%
from data_function import *

# %%
eightgencivic = get_all_search('owner','civic',2006,2011,0,100000)

# %%
eightgencivic
# Out:
#                                             post_title mileage  price  \
# 0             2008 Honda Civic LX clean title LOW MILE   88700   6999
# 1     Honda Civic Hybrid 2006* Clean Title*V.Low miles   56650   5999
# 2                     2010 Honda Civic EX Coupe 2 Door   85250   8500
# 3                                       Honda Civic si           5000
# 4    2007 HONDA CIVIC EX, 92K MILES, EXCELLENT COND...   92000   5250
# 5    2007 HONDA CIVIC HYBRID / 64,000 MILES / NAVIG...   64300   7500
# 6                        Honda Civic EX -- Low mileage   68700   7300
# 7                                  2007 Honda Civic Si  110000   8000
# 8    2010 Nissan Sentra S (Toyota Corolla/Honda Civ...  123712   5950
# 9                              Honda Civic Hybrid 2008  208000   4000
# 10                                      09 Honda Civic  112000   6500
# 11                           2011 HONDA CIVIC LX Sedan  106056   7500
# ...
