# %%
import requests_cache

# %%
requests_cache.install_cache('craigslist_cache')

# %%
from data_function import *

# %%
bmw335i = get_all_search('cto','335i',2009,2013,100,100000)

# %%
bmw335i
# Out:
#                                             post_title mileage  price  \
# 0              2013 BMW 335i coupe with 6 speed manual   65000  20000
# 1                         2012 BMW 335i 2-door M-sport      79  15500
# 2                              2010 E92 BMW 335i Coupe   42000  18000
# 3                            2011 BMW 335i convertible          15000
# 4                            BMW 335I Twin Turbo Coupe   67500  13500
# 5    Bmw 335i 2011 sedan 320HP N55 Less than 40k miles   39000  21500
# 6                            2009 bmw 335i   83k miles   83000   8900
# 7                            2011 BMW 335i convertible          15000
# 8    2011 BMW 335i E90 LOW MILES TWIN TURBO NAVIGAT...   66000  15500
# 9                            2011 bmw 335i convertible          18000
# 10                                 BMW 335i twin turbo   63000  15000
# 11   2013 BMW 335i - Tech, Premium, Cold Weather & ...   56000  20000
# ...
